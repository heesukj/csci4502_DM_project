# %%
# %pylab inline
import math
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
jan = pd.read_csv('chicago_taxi_trips_2016_01.csv')
jan.head()
# jan.info()jan.describe()
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0     85.0   2016-1-13 06:15:00  2016-1-13 06:15:00         180.0        0.40
# 1   2776.0   2016-1-22 09:30:00  2016-1-22 09:45:00         240.0        0.70
# 2   3168.0   2016-1-31 21:30:00  2016-1-31 21:30:00           0.0        0.00
# 3   4237.0   2016-1-23 17:30:00  2016-1-23 17:30:00         480.0        1.10
# 4   5710.0   2016-1-14 05:45:00  2016-1-14 06:00:00         480.0        2.71
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                   NaN                   24.0
# 1                  NaN                   NaN                    NaN
# 2                  NaN                   NaN                    NaN
# 3                  NaN                   NaN                    6.0
# 4                  NaN                   NaN                   32.0
#
#    dropoff_community_area   fare  tips  tolls  extras  trip_total  \
# ...

# %%
jan.describe()
# Out:
#             taxi_id  trip_seconds    trip_miles  pickup_census_tract  \
# count  1.705782e+06  1.705491e+06  1.705791e+06                  0.0
# mean   4.389323e+03  6.534422e+02  2.872702e+00                  NaN
# std    2.515819e+03  9.327260e+02  1.810793e+01                  NaN
# min    0.000000e+00  0.000000e+00  0.000000e+00                  NaN
# 25%    2.242000e+03  2.400000e+02  0.000000e+00                  NaN
# 50%    4.386000e+03  4.800000e+02  1.000000e+00                  NaN
# 75%    6.591000e+03  8.400000e+02  2.400000e+00                  NaN
# max    8.762000e+03  8.634000e+04  3.280000e+03                  NaN
#
#        dropoff_census_tract  pickup_community_area  dropoff_community_area  \
# count         967479.000000           1.420016e+06            1.392150e+06
# mean             516.822016           2.322074e+01            2.099069e+01
# std              357.586612           1.981936e+01            1.737237e+01
# ...

# %%
# Delete this column due to no values are applicable
del jan['pickup_census_tract']

# %%
jan.head(10)
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0     85.0   2016-1-13 06:15:00  2016-1-13 06:15:00         180.0        0.40
# 1   2776.0   2016-1-22 09:30:00  2016-1-22 09:45:00         240.0        0.70
# 2   3168.0   2016-1-31 21:30:00  2016-1-31 21:30:00           0.0        0.00
# 3   4237.0   2016-1-23 17:30:00  2016-1-23 17:30:00         480.0        1.10
# 4   5710.0   2016-1-14 05:45:00  2016-1-14 06:00:00         480.0        2.71
# 5   1987.0    2016-1-8 18:15:00   2016-1-8 18:45:00        1080.0        6.20
# 6   4986.0   2016-1-14 04:30:00  2016-1-14 05:00:00        1500.0       18.40
# 7   6400.0   2016-1-26 04:15:00  2016-1-26 04:15:00          60.0        0.20
# 8   7418.0   2016-1-22 11:30:00  2016-1-22 11:45:00         180.0        0.00
# 9   6450.0    2016-1-7 21:15:00   2016-1-7 21:15:00           0.0        0.00
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area   fare  \
# ...

# %%
jan['dropoff_census_tract'].dropna()
# Out:
# 8           504.0
# 10          792.0
# 11          807.0
# 13          749.0
# 15          807.0
# 16           40.0
# 19          404.0
# 20          749.0
# 21          108.0
# 23           13.0
# 25          960.0
# 26          504.0
# 30          504.0
# 31          959.0
# 34          179.0
# 36         1077.0
# 37           16.0
# 38          504.0
# 40          805.0
# 41          805.0
# 43          792.0
# 44          787.0
# 45           16.0
# 47           13.0
# 48           16.0
# 49          787.0
# 51          134.0
# 52           16.0
# 53          911.0
# 57          515.0
#             ...
# 1705759      40.0
# 1705760     313.0
# 1705761      16.0
# 1705762     615.0
# 1705763     911.0
# 1705764     504.0
# 1705765      16.0
# 1705766     970.0
# 1705767     307.0
# 1705770      40.0
# 1705771      16.0
# 1705772     515.0
# 1705773      16.0
# 1705775     316.0
# 1705779     854.0
# 1705780     504.0
# 1705784     807.0
# 1705785     735.0
# 1705787     970.0
# ...

# %%
jan.dropna()
# jan[pd.notnull(jan.index)]
# Out:
#          taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 8         7418.0   2016-1-22 11:30:00  2016-1-22 11:45:00         180.0
# 10        1078.0   2016-1-25 09:00:00  2016-1-25 09:00:00         480.0
# 11        6641.0    2016-1-6 23:15:00   2016-1-6 23:30:00         420.0
# 13        7984.0   2016-1-22 09:45:00  2016-1-22 09:45:00         420.0
# 15         221.0    2016-1-3 16:30:00   2016-1-3 16:30:00         720.0
# 16        6535.0   2016-1-25 10:30:00  2016-1-25 10:30:00         720.0
# 19        4251.0    2016-1-1 19:30:00   2016-1-1 19:45:00         660.0
# 21        5132.0    2016-1-8 19:30:00   2016-1-8 19:30:00         720.0
# 23        2647.0   2016-1-15 19:30:00  2016-1-15 19:30:00         360.0
# 26        4126.0   2016-1-23 21:45:00  2016-1-23 21:45:00         360.0
# 30         373.0    2016-1-2 17:45:00   2016-1-2 17:45:00         240.0
# 31        5540.0   2016-1-13 19:00:00  2016-1-13 19:15:00         600.0
# ...

# %%
# jan.describe()
# jan.info()
len(jan.dropna())
# Out:
# 615075

# %%
feb = pd.read_csv('chicago_taxi_trips_2016_02.csv')
feb.head()
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0     53.0   2016-2-28 04:30:00  2016-2-28 04:45:00         840.0        0.30
# 1   8147.0   2016-2-10 11:30:00  2016-2-10 11:45:00         480.0        1.01
# 2   6234.0   2016-2-18 15:15:00  2016-2-18 15:15:00         180.0        0.40
# 3   6434.0   2016-2-17 22:00:00  2016-2-17 22:00:00         420.0        2.30
# 4     64.0   2016-2-22 13:45:00  2016-2-22 14:00:00        1200.0       17.10
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                   NaN                    7.0
# 1                  NaN                 504.0                   28.0
# 2                  NaN                  16.0                   32.0
# 3                  NaN                   NaN                    NaN
# 4                  NaN                 313.0                   28.0
#
#    dropoff_community_area   fare  tips  tolls  extras  trip_total  \
# ...

# %%
del feb['pickup_census_tract']
len(feb.dropna())
# Out:
# 646037

# %%
# join two dataframes

jan_feb = pd.concat([jan.dropna(), feb.dropna()])
jan_feb.head()
# Out:
#     taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 8    7418.0   2016-1-22 11:30:00  2016-1-22 11:45:00         180.0
# 10   1078.0   2016-1-25 09:00:00  2016-1-25 09:00:00         480.0
# 11   6641.0    2016-1-6 23:15:00   2016-1-6 23:30:00         420.0
# 13   7984.0   2016-1-22 09:45:00  2016-1-22 09:45:00         420.0
# 15    221.0    2016-1-3 16:30:00   2016-1-3 16:30:00         720.0
#
#     trip_miles  dropoff_census_tract  pickup_community_area  \
# 8          0.0                 504.0                    8.0
# 10         1.3                 792.0                    8.0
# 11         0.0                 807.0                    8.0
# 13         0.0                 749.0                    8.0
# 15         0.0                 807.0                    7.0
#
#     dropoff_community_area   fare  tips  tolls  extras  trip_total  \
# 8                     32.0   5.00   2.0    0.0     1.5        8.50
# ...

# %%
len(jan_feb)
# Out:
# 1261112
