# %%
get_ipython().magic('pylab inline')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(arange(5))

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
taxi4 = pd.read_csv("/Users/reiisobe/Downloads/chicago-taxi-rides-2016/chicago_taxi_trips_2016_04.csv")

# %%
taxi4.head(6)
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   3853.0    2016-4-5 08:15:00   2016-4-5 09:00:00        2580.0        0.70
# 1   1764.0   2016-4-16 09:30:00  2016-4-16 09:30:00           0.0        0.00
# 2    475.0   2016-4-10 14:45:00  2016-4-10 14:45:00         420.0        0.98
# 3    208.0    2016-4-4 16:45:00   2016-4-4 16:45:00         540.0        1.45
# 4   1220.0   2016-4-11 15:00:00  2016-4-11 15:00:00         660.0        0.00
# 5   2749.0   2016-4-22 10:30:00  2016-4-22 11:00:00         960.0        5.40
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                 911.0                   56.0
# 1                  NaN                   NaN                    NaN
# 2                  NaN                 899.0                   32.0
# 3                  NaN                 805.0                   32.0
# 4                  NaN                 807.0                    8.0
# ...

# %%
taxi4.describe()
# Out:
#             taxi_id  trip_seconds    trip_miles  pickup_census_tract  \
# count  1.952123e+06  1.951053e+06  1.952141e+06                  0.0
# mean   4.370197e+03  7.323746e+02  4.035661e+00                  NaN
# std    2.533704e+03  9.635501e+02  3.814863e+01                  NaN
# min    0.000000e+00  0.000000e+00  0.000000e+00                  NaN
# 25%    2.206000e+03  3.000000e+02  0.000000e+00                  NaN
# 50%    4.341000e+03  5.400000e+02  1.000000e+00                  NaN
# 75%    6.596000e+03  9.000000e+02  2.600000e+00                  NaN
# max    8.762000e+03  8.638800e+04  3.300000e+03                  NaN
#
#        dropoff_census_tract  pickup_community_area  dropoff_community_area  \
# count          1.167725e+06           1.621668e+06            1.585728e+06
# mean           5.231158e+02           2.372745e+01            2.188345e+01
# std            3.551600e+02           2.000665e+01            1.795832e+01
# ...

# %%
taxi4.pop('taxi_id')
# Out:
# 0          3853.0
# 1          1764.0
# 2           475.0
# 3           208.0
# 4          1220.0
# 5          2749.0
# 6          3590.0
# 7          5360.0
# 8          5723.0
# 9          4123.0
# 10         2271.0
# 11         3808.0
# 12         6833.0
# 13         4411.0
# 14         5771.0
# 15         6459.0
# 16         4113.0
# 17         4195.0
# 18         5217.0
# 19         3062.0
# 20          841.0
# 21         4473.0
# 22          751.0
# 23         2929.0
# 24         3467.0
# 25         6847.0
# 26         4386.0
# 27         3754.0
# 28         6747.0
# 29         2873.0
#             ...
# 1952122    7710.0
# 1952123    6449.0
# 1952124    4303.0
# 1952125    4728.0
# 1952126    4728.0
# 1952127    3763.0
# 1952128    2707.0
# 1952129    7695.0
# 1952130    7626.0
# 1952131    5226.0
# 1952132     761.0
# 1952133    3143.0
# 1952134    7844.0
# 1952135     965.0
# 1952136    5723.0
# 1952137    7758.0
# 1952138    1113.0
# 1952139    4438.0
# 1952140    7826.0
# ...

# %%
taxi4.describe()
# Out:
#        trip_seconds    trip_miles  pickup_census_tract  dropoff_census_tract  \
# count  1.951053e+06  1.952141e+06                  0.0          1.167725e+06
# mean   7.323746e+02  4.035661e+00                  NaN          5.231158e+02
# std    9.635501e+02  3.814863e+01                  NaN          3.551600e+02
# min    0.000000e+00  0.000000e+00                  NaN          2.000000e+00
# 25%    3.000000e+02  0.000000e+00                  NaN          2.250000e+02
# 50%    5.400000e+02  1.000000e+00                  NaN          5.040000e+02
# 75%    9.000000e+02  2.600000e+00                  NaN          8.990000e+02
# max    8.638800e+04  3.300000e+03                  NaN          1.140000e+03
#
#        pickup_community_area  dropoff_community_area          fare  \
# count           1.621668e+06            1.585728e+06  1.952133e+06
# mean            2.372745e+01            2.188345e+01  1.404664e+01
# std             2.000665e+01            1.795832e+01  1.841246e+01
# ...

# %%
taxi4.pop('pickup_census_tract')
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#            ..
# 1952122   NaN
# 1952123   NaN
# 1952124   NaN
# 1952125   NaN
# 1952126   NaN
# 1952127   NaN
# 1952128   NaN
# 1952129   NaN
# 1952130   NaN
# 1952131   NaN
# 1952132   NaN
# 1952133   NaN
# 1952134   NaN
# 1952135   NaN
# 1952136   NaN
# 1952137   NaN
# 1952138   NaN
# 1952139   NaN
# 1952140   NaN
# 1952141   NaN
# 1952142   NaN
# 1952143   NaN
# 1952144   NaN
# 1952145   NaN
# 1952146   NaN
# 1952147   NaN
# 1952148   NaN
# 1952149   NaN
# 1952150   NaN
# 1952151   NaN
# ...

# %%
taxi4.pop('dropoff_census_tract')
# Out:
# 0           911.0
# 1             NaN
# 2           899.0
# 3           805.0
# 4           807.0
# 5             NaN
# 6             NaN
# 7           334.0
# 8          1077.0
# 9             NaN
# 10           40.0
# 11          380.0
# 12           16.0
# 13          982.0
# 14          602.0
# 15            NaN
# 16            NaN
# 17          685.0
# 18          911.0
# 19          970.0
# 20            NaN
# 21          911.0
# 22           16.0
# 23          676.0
# 24           16.0
# 25            NaN
# 26            NaN
# 27          313.0
# 28          313.0
# 29            NaN
#             ...
# 1952122     225.0
# 1952123      16.0
# 1952124       NaN
# 1952125     607.0
# 1952126     316.0
# 1952127     313.0
# 1952128       NaN
# 1952129     504.0
# 1952130       NaN
# 1952131       NaN
# 1952132      16.0
# 1952133     504.0
# 1952134     807.0
# 1952135      40.0
# 1952136     805.0
# 1952137       NaN
# 1952138     307.0
# 1952139     334.0
# 1952140     307.0
# ...

# %%
taxi4.describe()
# Out:
#        trip_seconds    trip_miles  pickup_community_area  \
# count  1.951053e+06  1.952141e+06           1.621668e+06
# mean   7.323746e+02  4.035661e+00           2.372745e+01
# std    9.635501e+02  3.814863e+01           2.000665e+01
# min    0.000000e+00  0.000000e+00           1.000000e+00
# 25%    3.000000e+02  0.000000e+00           8.000000e+00
# 50%    5.400000e+02  1.000000e+00           2.400000e+01
# 75%    9.000000e+02  2.600000e+00           3.200000e+01
# max    8.638800e+04  3.300000e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            1.585728e+06  1.952133e+06  1.952133e+06  1.952133e+06
# mean             2.188345e+01  1.404664e+01  1.740916e+00  2.563160e-03
# std              1.795832e+01  1.841246e+01  2.949194e+00  2.353782e-01
# min              1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%              8.000000e+00  6.250000e+00  0.000000e+00  0.000000e+00
# ...

# %%
taxi4.head(0)
# Out:
# Empty DataFrame
# Columns: [trip_start_timestamp, trip_end_timestamp, trip_seconds, trip_miles, pickup_community_area, dropoff_community_area, fare, tips, tolls, extras, trip_total, payment_type, company, pickup_latitude, pickup_longitude, dropoff_latitude, dropoff_longitude]
# Index: []

# %%
taxi4.head(1)
# Out:
#   trip_start_timestamp trip_end_timestamp  trip_seconds  trip_miles  \
# 0    2016-4-5 08:15:00  2016-4-5 09:00:00        2580.0         0.7
#
#    pickup_community_area  dropoff_community_area   fare  tips  tolls  extras  \
# 0                   56.0                     8.0  34.75  7.85    0.0     4.5
#
#    trip_total payment_type  company  pickup_latitude  pickup_longitude  \
# 0        47.1  Credit Card    107.0            433.0             757.0
#
#    dropoff_latitude  dropoff_longitude
# 0             688.0              206.0

# %%
taxi4.tips
# Out:
# 0           7.85
# 1           5.00
# 2           1.00
# 3           0.00
# 4           0.00
# 5           2.00
# 6           0.00
# 7           0.00
# 8           0.00
# 9           0.00
# 10          0.00
# 11          2.15
# 12          0.00
# 13          2.50
# 14          0.00
# 15          0.00
# 16          0.95
# 17          0.00
# 18          0.00
# 19          0.00
# 20          2.10
# 21          2.00
# 22          2.00
# 23          0.00
# 24          0.00
# 25          2.00
# 26          6.15
# 27          5.00
# 28         10.40
# 29          5.20
#            ...
# 1952122     3.00
# 1952123     0.00
# 1952124     0.00
# 1952125     1.00
# 1952126     2.00
# 1952127    40.00
# 1952128     0.00
# 1952129     3.00
# 1952130     1.00
# 1952131     0.00
# 1952132     0.00
# 1952133     0.00
# 1952134     0.00
# 1952135     2.00
# 1952136     3.00
# 1952137     0.08
# 1952138     0.00
# 1952139     0.00
# 1952140     0.00
# 1952141     1.00
# 1952142     1.00
# ...

# %%
taxi4.pop('extras')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-20f01b0735e4> in <module>()
# ----> 1 taxi4.pop('extras')
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in pop(self, item)
#     548         Return item and drop from frame. Raise KeyError if not found.
#     549         """
# --> 550         result = self[item]
#     551         del self[item]
#     552         try:
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1969         # get column
# ...

# %%
taxi4.describe()
taxi4.pop('company')
taxi4.pop('pickup_latitude')
taxi4.pop('pickup_longitude')
taxi4.pop('dropoff_latitude')
taxi4.pop('dropoff_longitude')
taxi4.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ee035ed393e4> in <module>()
#       1 taxi4.describe()
# ----> 2 taxi4.pop('company')
#       3 taxi4.pop('pickup_latitude')
#       4 taxi4.pop('pickup_longitude')
#       5 taxi4.pop('dropoff_latitude')
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in pop(self, item)
#     548         Return item and drop from frame. Raise KeyError if not found.
#     549         """
# --> 550         result = self[item]
#     551         del self[item]
#     552         try:
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ...

# %%
taxi4.describe()
# Out:
#        trip_seconds    trip_miles  pickup_community_area  \
# count  1.951053e+06  1.952141e+06           1.621668e+06
# mean   7.323746e+02  4.035661e+00           2.372745e+01
# std    9.635501e+02  3.814863e+01           2.000665e+01
# min    0.000000e+00  0.000000e+00           1.000000e+00
# 25%    3.000000e+02  0.000000e+00           8.000000e+00
# 50%    5.400000e+02  1.000000e+00           2.400000e+01
# 75%    9.000000e+02  2.600000e+00           3.200000e+01
# max    8.638800e+04  3.300000e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            1.585728e+06  1.952133e+06  1.952133e+06  1.952133e+06
# mean             2.188345e+01  1.404664e+01  1.740916e+00  2.563160e-03
# std              1.795832e+01  1.841246e+01  2.949194e+00  2.353782e-01
# min              1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%              8.000000e+00  6.250000e+00  0.000000e+00  0.000000e+00
# ...

# %%
taxi4.pop('pickup_longitude');
taxi4.pop('dropoff_latitude');
taxi4.pop('dropoff_longitude');
taxi4.describe();

# %%
taxi4.describe()
# Out:
#        trip_seconds    trip_miles  pickup_community_area  \
# count  1.951053e+06  1.952141e+06           1.621668e+06
# mean   7.323746e+02  4.035661e+00           2.372745e+01
# std    9.635501e+02  3.814863e+01           2.000665e+01
# min    0.000000e+00  0.000000e+00           1.000000e+00
# 25%    3.000000e+02  0.000000e+00           8.000000e+00
# 50%    5.400000e+02  1.000000e+00           2.400000e+01
# 75%    9.000000e+02  2.600000e+00           3.200000e+01
# max    8.638800e+04  3.300000e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            1.585728e+06  1.952133e+06  1.952133e+06  1.952133e+06
# mean             2.188345e+01  1.404664e+01  1.740916e+00  2.563160e-03
# std              1.795832e+01  1.841246e+01  2.949194e+00  2.353782e-01
# min              1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%              8.000000e+00  6.250000e+00  0.000000e+00  0.000000e+00
# ...

# %%
taxi7 = pd.read_csv("/Users/reiisobe/Downloads/chicago-taxi-rides-2016/chicago_taxi_trips_2016_07.csv");
taxi8 = pd.read_csv("/Users/reiisobe/Downloads/chicago-taxi-rides-2016/chicago_taxi_trips_2016_08.csv");
taxi9 = pd.read_csv("/Users/reiisobe/Downloads/chicago-taxi-rides-2016/chicago_taxi_trips_2016_09.csv");

# %%
taxi7.head(1)
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   3977.0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0         0.1
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                 807.0                    8.0
#
#    dropoff_community_area   fare  tips  tolls  extras  trip_total  \
# 0                    28.0  10.25   0.0    0.0     2.5       12.75
#
#   payment_type  company  pickup_latitude  pickup_longitude  dropoff_latitude  \
# 0         Cash    107.0            413.0             636.0             411.0
#
#    dropoff_longitude
# 0              545.0

# %%
taxi8.head(1)
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   7106.0   2016-8-15 16:30:00  2016-8-15 16:45:00         360.0         0.6
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                  40.0                   32.0
#
#    dropoff_community_area  fare  tips  tolls  extras  trip_total payment_type  \
# 0                    28.0   6.0   0.0    0.0     0.0         6.0         Cash
#
#    company  pickup_latitude  pickup_longitude  dropoff_latitude  \
# 0    107.0             18.0             610.0             395.0
#
#    dropoff_longitude
# 0              408.0

# %%
taxi9.head(1)
# Out:
#    taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2863.0   2016-9-24 15:45:00  2016-9-24 15:45:00         540.0         0.0
#
#    pickup_census_tract  dropoff_census_tract  pickup_community_area  \
# 0                  NaN                 307.0                   33.0
#
#    dropoff_community_area  fare  tips  tolls  extras  trip_total payment_type  \
# 0                    32.0   8.0   0.0    0.0     0.0         8.0         Cash
#
#    company  pickup_latitude  pickup_longitude  dropoff_latitude  \
# 0    107.0            728.0             277.0              64.0
#
#    dropoff_longitude
# 0              231.0

# %%
taxi7.pop('pickup_census_tract');
taxi7.pop('dropoff_census_tract');
taxi7.pop('pickup_latitude');
taxi7.pop('pickup_longitude');
taxi7.pop('dropoff_latitude');
taxi7.pop('dropoff_longitude');
taxi7.pop('extras');
taxi7.pop('taxi_id');
taxi7.pop('company');

# %%
taxi7.describe();

# %%
taxi7.head(1)
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0         0.1
#
#    pickup_community_area  dropoff_community_area   fare  tips  tolls  \
# 0                    8.0                    28.0  10.25   0.0    0.0
#
#    trip_total payment_type
# 0       12.75         Cash

# %%
taxi8.pop('pickup_census_tract');
taxi8.pop('dropoff_census_tract');
taxi8.pop('pickup_latitude');
taxi8.pop('pickup_longitude');
taxi8.pop('dropoff_latitude');
taxi8.pop('dropoff_longitude');
taxi8.pop('extras');
taxi8.pop('taxi_id');
taxi8.pop('company');
taxi9.pop('pickup_census_tract');
taxi9.pop('dropoff_census_tract');
taxi9.pop('pickup_latitude');
taxi9.pop('pickup_longitude');
taxi9.pop('dropoff_latitude');
taxi9.pop('dropoff_longitude');
taxi9.pop('extras');
taxi9.pop('taxi_id');
taxi9.pop('company');

# %%
taxi8.head(1);
taxi9.head(1);

# %%
taxi8.head(1)
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-8-15 16:30:00  2016-8-15 16:45:00         360.0         0.6
#
#    pickup_community_area  dropoff_community_area  fare  tips  tolls  \
# 0                   32.0                    28.0   6.0   0.0    0.0
#
#    trip_total payment_type
# 0         6.0         Cash

# %%
taxi9.head(1)
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-9-24 15:45:00  2016-9-24 15:45:00         540.0         0.0
#
#    pickup_community_area  dropoff_community_area  fare  tips  tolls  \
# 0                   33.0                    32.0   8.0   0.0    0.0
#
#    trip_total payment_type
# 0         8.0         Cash

# %%
taxi9.head()
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-9-24 15:45:00  2016-9-24 15:45:00         540.0         0.0
# 1   2016-9-25 15:45:00  2016-9-25 16:30:00        1980.0        11.7
# 2   2016-9-21 16:15:00  2016-9-21 18:00:00        5580.0         0.0
# 3    2016-9-6 16:30:00   2016-9-6 17:45:00        4620.0        22.1
# 4   2016-9-28 19:15:00  2016-9-28 19:30:00        1380.0         3.7
#
#    pickup_community_area  dropoff_community_area   fare   tips  tolls  \
# 0                   33.0                    32.0   8.00   0.00    0.0
# 1                   32.0                    56.0  31.25   0.00    0.0
# 2                   33.0                    76.0  57.25  11.75    0.0
# 3                    8.0                    76.0  61.25  12.25    0.0
# 4                    8.0                     7.0  14.50   3.30    0.0
#
#    trip_total payment_type
# 0        8.00         Cash
# 1       33.25         Cash
# 2       70.50  Credit Card
# ...

# %%
taxi4.merge(taxi7, how = 'outer')
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0          2016-4-5 08:15:00   2016-4-5 09:00:00        2580.0        0.70
# 1         2016-4-16 09:30:00  2016-4-16 09:30:00           0.0        0.00
# 2         2016-4-10 14:45:00  2016-4-10 14:45:00         420.0        0.98
# 3          2016-4-4 16:45:00   2016-4-4 16:45:00         540.0        1.45
# 4         2016-4-11 15:00:00  2016-4-11 15:00:00         660.0        0.00
# 5         2016-4-22 10:30:00  2016-4-22 11:00:00         960.0        5.40
# 6          2016-4-9 14:45:00   2016-4-9 15:00:00        1260.0        0.10
# 7         2016-4-16 12:00:00  2016-4-16 12:15:00         540.0        1.20
# 8         2016-4-10 23:00:00  2016-4-10 23:00:00         420.0      140.00
# 9          2016-4-5 10:45:00   2016-4-5 10:45:00         600.0        1.90
# 10         2016-4-2 14:30:00   2016-4-2 14:30:00           0.0        0.00
# ...

# %%
taxi7.describe()
# Out:
#        trip_seconds    trip_miles  pickup_community_area  \
# count  1.745288e+06  1.745355e+06           1.504806e+06
# mean   8.034312e+02  3.560528e+00           2.333095e+01
# std    1.104149e+03  1.008085e+01           1.990311e+01
# min    0.000000e+00  0.000000e+00           1.000000e+00
# 25%    3.600000e+02  1.000000e-01           8.000000e+00
# 50%    6.000000e+02  1.100000e+00           2.200000e+01
# 75%    9.600000e+02  3.000000e+00           3.200000e+01
# max    8.638200e+04  3.353100e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            1.491258e+06  1.745352e+06  1.745352e+06  1.745352e+06
# mean             2.154566e+01  1.404946e+01  1.593312e+00  2.719406e-03
# std              1.766388e+01  2.058892e+01  2.857753e+00  2.115446e-01
# min              1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%              8.000000e+00  6.500000e+00  0.000000e+00  0.000000e+00
# ...

# %%
taxi7.tips
# Out:
# 0          0.00
# 1          0.00
# 2          3.55
# 3          2.00
# 4          0.00
# 5          2.00
# 6          0.00
# 7          0.00
# 8          1.00
# 9          0.00
# 10         0.00
# 11         2.00
# 12         5.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         4.00
# 19         0.00
# 20         2.00
# 21         9.55
# 22         2.00
# 23         0.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         1.50
# 29         2.65
#            ...
# 1745357    1.90
# 1745358    0.00
# 1745359    3.00
# 1745360    5.00
# 1745361    0.00
# 1745362    2.00
# 1745363    0.00
# 1745364    0.00
# 1745365    0.00
# 1745366    1.70
# 1745367    0.00
# 1745368    0.00
# 1745369    3.85
# 1745370    0.00
# 1745371    3.00
# 1745372    2.00
# 1745373    0.00
# 1745374    0.00
# 1745375    0.00
# 1745376    1.00
# 1745377    0.00
# 1745378    0.00
# 1745379    1.50
# 1745380    3.00
# ...

# %%
taxi = taxi7

# %%
taxi.tips
# Out:
# 0          0.00
# 1          0.00
# 2          3.55
# 3          2.00
# 4          0.00
# 5          2.00
# 6          0.00
# 7          0.00
# 8          1.00
# 9          0.00
# 10         0.00
# 11         2.00
# 12         5.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         4.00
# 19         0.00
# 20         2.00
# 21         9.55
# 22         2.00
# 23         0.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         1.50
# 29         2.65
#            ...
# 1745357    1.90
# 1745358    0.00
# 1745359    3.00
# 1745360    5.00
# 1745361    0.00
# 1745362    2.00
# 1745363    0.00
# 1745364    0.00
# 1745365    0.00
# 1745366    1.70
# 1745367    0.00
# 1745368    0.00
# 1745369    3.85
# 1745370    0.00
# 1745371    3.00
# 1745372    2.00
# 1745373    0.00
# 1745374    0.00
# 1745375    0.00
# 1745376    1.00
# 1745377    0.00
# 1745378    0.00
# 1745379    1.50
# 1745380    3.00
# ...

# %%
taxi.merge(taxi8, how = 'outer')
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0         2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1         2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 2         2016-7-15 13:45:00  2016-7-15 14:00:00         642.0        4.22
# 3         2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
# 4         2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0       17.50
# 5         2016-7-26 10:30:00  2016-7-26 10:45:00         960.0        2.10
# 6          2016-7-8 16:15:00   2016-7-8 16:15:00         480.0        0.60
# 7          2016-7-2 00:00:00   2016-7-2 00:15:00         600.0        0.00
# 8         2016-7-28 13:30:00  2016-7-28 13:45:00         420.0        0.60
# 9         2016-7-16 09:45:00  2016-7-16 10:00:00         840.0        2.30
# 10        2016-7-19 20:00:00  2016-7-19 20:15:00         540.0        4.20
# ...

# %%
taxi.merge(taxi9, how = 'outer')
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0         2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1         2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 2         2016-7-15 13:45:00  2016-7-15 14:00:00         642.0        4.22
# 3         2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
# 4         2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0       17.50
# 5         2016-7-26 10:30:00  2016-7-26 10:45:00         960.0        2.10
# 6          2016-7-8 16:15:00   2016-7-8 16:15:00         480.0        0.60
# 7          2016-7-2 00:00:00   2016-7-2 00:15:00         600.0        0.00
# 8         2016-7-28 13:30:00  2016-7-28 13:45:00         420.0        0.60
# 9         2016-7-16 09:45:00  2016-7-16 10:00:00         840.0        2.30
# 10        2016-7-19 20:00:00  2016-7-19 20:15:00         540.0        4.20
# ...

# %%
taxi.tips
# Out:
# 0          0.00
# 1          0.00
# 2          3.55
# 3          2.00
# 4          0.00
# 5          2.00
# 6          0.00
# 7          0.00
# 8          1.00
# 9          0.00
# 10         0.00
# 11         2.00
# 12         5.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         4.00
# 19         0.00
# 20         2.00
# 21         9.55
# 22         2.00
# 23         0.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         1.50
# 29         2.65
#            ...
# 1745357    1.90
# 1745358    0.00
# 1745359    3.00
# 1745360    5.00
# 1745361    0.00
# 1745362    2.00
# 1745363    0.00
# 1745364    0.00
# 1745365    0.00
# 1745366    1.70
# 1745367    0.00
# 1745368    0.00
# 1745369    3.85
# 1745370    0.00
# 1745371    3.00
# 1745372    2.00
# 1745373    0.00
# 1745374    0.00
# 1745375    0.00
# 1745376    1.00
# 1745377    0.00
# 1745378    0.00
# 1745379    1.50
# 1745380    3.00
# ...

# %%
taxi = taxi.merge(taxi8, how = 'outer')

# %%
taxi.tips
# Out:
# 0          0.00
# 1          0.00
# 2          3.55
# 3          2.00
# 4          0.00
# 5          2.00
# 6          0.00
# 7          0.00
# 8          1.00
# 9          0.00
# 10         0.00
# 11         2.00
# 12         5.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         4.00
# 19         0.00
# 20         2.00
# 21         9.55
# 22         2.00
# 23         0.00
# 24         0.00
# 25         0.00
# 26         0.00
# 27         0.00
# 28         1.50
# 29         2.65
#            ...
# 3269304    2.00
# 3269305    0.00
# 3269306    4.00
# 3269307    1.50
# 3269308    0.00
# 3269309    0.00
# 3269310    0.00
# 3269311    0.00
# 3269312    0.00
# 3269313    0.00
# 3269314    2.00
# 3269315    0.00
# 3269316    0.00
# 3269317    0.00
# 3269318    2.85
# 3269319    3.00
# 3269320    3.00
# 3269321    2.00
# 3269322    0.00
# 3269323    1.75
# 3269324    2.00
# 3269325    0.00
# 3269326    0.00
# 3269327    4.00
# ...

# %%
taxi = taxi.merge(taxi9, how = 'outer')

# %%
taxi.tips
# Out:
# 0           0.00
# 1           0.00
# 2           3.55
# 3           2.00
# 4           0.00
# 5           2.00
# 6           0.00
# 7           0.00
# 8           1.00
# 9           0.00
# 10          0.00
# 11          2.00
# 12          5.00
# 13          0.00
# 14          0.00
# 15          0.00
# 16          0.00
# 17          0.00
# 18          4.00
# 19          0.00
# 20          2.00
# 21          9.55
# 22          2.00
# 23          0.00
# 24          0.00
# 25          0.00
# 26          0.00
# 27          0.00
# 28          1.50
# 29          2.65
#            ...
# 4563324     0.00
# 4563325     0.00
# 4563326     0.00
# 4563327     2.00
# 4563328     2.00
# 4563329     0.00
# 4563330     0.00
# 4563331     3.60
# 4563332     2.00
# 4563333     7.75
# 4563334     0.00
# 4563335     0.00
# 4563336     0.00
# 4563337     0.00
# 4563338     3.00
# 4563339     0.00
# 4563340     0.00
# 4563341     0.00
# 4563342     0.00
# 4563343     1.00
# 4563344     2.30
# ...

# %%
taxi9.tips
# Out:
# 0           0.00
# 1           0.00
# 2          11.75
# 3          12.25
# 4           3.30
# 5           6.30
# 6           0.00
# 7           2.00
# 8           0.00
# 9           0.00
# 10          0.00
# 11          0.00
# 12          1.00
# 13          0.00
# 14         10.80
# 15          0.00
# 16          0.00
# 17          1.00
# 18          0.00
# 19          8.75
# 20          1.00
# 21          0.00
# 22          2.00
# 23          2.30
# 24          3.25
# 25          0.00
# 26          2.00
# 27          0.00
# 28          0.00
# 29          0.00
#            ...
# 1293990     0.00
# 1293991     0.00
# 1293992     0.00
# 1293993     2.00
# 1293994     2.00
# 1293995     0.00
# 1293996     0.00
# 1293997     3.60
# 1293998     2.00
# 1293999     7.75
# 1294000     0.00
# 1294001     0.00
# 1294002     0.00
# 1294003     0.00
# 1294004     3.00
# 1294005     0.00
# 1294006     0.00
# 1294007     0.00
# 1294008     0.00
# 1294009     1.00
# 1294010     2.30
# ...

# %%
taxi.tips
# Out:
# 0           0.00
# 1           0.00
# 2           3.55
# 3           2.00
# 4           0.00
# 5           2.00
# 6           0.00
# 7           0.00
# 8           1.00
# 9           0.00
# 10          0.00
# 11          2.00
# 12          5.00
# 13          0.00
# 14          0.00
# 15          0.00
# 16          0.00
# 17          0.00
# 18          4.00
# 19          0.00
# 20          2.00
# 21          9.55
# 22          2.00
# 23          0.00
# 24          0.00
# 25          0.00
# 26          0.00
# 27          0.00
# 28          1.50
# 29          2.65
#            ...
# 4563324     0.00
# 4563325     0.00
# 4563326     0.00
# 4563327     2.00
# 4563328     2.00
# 4563329     0.00
# 4563330     0.00
# 4563331     3.60
# 4563332     2.00
# 4563333     7.75
# 4563334     0.00
# 4563335     0.00
# 4563336     0.00
# 4563337     0.00
# 4563338     3.00
# 4563339     0.00
# 4563340     0.00
# 4563341     0.00
# 4563342     0.00
# 4563343     1.00
# 4563344     2.30
# ...

# %%
taxi.head(4)
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0        4.22
# 3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
#
#    pickup_community_area  dropoff_community_area   fare  tips  tolls  \
# 0                    8.0                    28.0  10.25  0.00    0.0
# 1                    8.0                    28.0   7.75  0.00    0.0
# 2                    NaN                     NaN  13.25  3.55    0.0
# 3                   32.0                     8.0  10.75  2.00    0.0
#
#    trip_total payment_type
# 0       12.75         Cash
# 1        7.75         Cash
# 2       21.30  Credit Card
# 3       13.25  Credit Card

# %%
taxi7.head(4)
# Out:
#   trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0        4.22
# 3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
#
#    pickup_community_area  dropoff_community_area   fare  tips  tolls  \
# 0                    8.0                    28.0  10.25  0.00    0.0
# 1                    8.0                    28.0   7.75  0.00    0.0
# 2                    NaN                     NaN  13.25  3.55    0.0
# 3                   32.0                     8.0  10.75  2.00    0.0
#
#    trip_total payment_type
# 0       12.75         Cash
# 1        7.75         Cash
# 2       21.30  Credit Card
# 3       13.25  Credit Card

# %%
taxi.to_csv("taxi_trips_7_to_9.csv")

# %%
taxi.tips;

# %%
taxi.count();

# %%
taxi.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d8b97436344> in <module>()
# ----> 1 taxi.count()
#
# NameError: name 'taxi' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
taxi4 = pd.read_csv("taxi_trips_7_to_9.csv")

# %%
taxi4.tips
# Out:
# 0           0.00
# 1           0.00
# 2           3.55
# 3           2.00
# 4           0.00
# 5           2.00
# 6           0.00
# 7           0.00
# 8           1.00
# 9           0.00
# 10          0.00
# 11          2.00
# 12          5.00
# 13          0.00
# 14          0.00
# 15          0.00
# 16          0.00
# 17          0.00
# 18          4.00
# 19          0.00
# 20          2.00
# 21          9.55
# 22          2.00
# 23          0.00
# 24          0.00
# 25          0.00
# 26          0.00
# 27          0.00
# 28          1.50
# 29          2.65
#            ...
# 4563324     0.00
# 4563325     0.00
# 4563326     0.00
# 4563327     2.00
# 4563328     2.00
# 4563329     0.00
# 4563330     0.00
# 4563331     3.60
# 4563332     2.00
# 4563333     7.75
# 4563334     0.00
# 4563335     0.00
# 4563336     0.00
# 4563337     0.00
# 4563338     3.00
# 4563339     0.00
# 4563340     0.00
# 4563341     0.00
# 4563342     0.00
# 4563343     1.00
# 4563344     2.30
# ...

# %%
taxi4.describe()
# Out:
#          Unnamed: 0  trip_seconds    trip_miles  pickup_community_area  \
# count  4.563354e+06  4.563088e+06  4.563271e+06           4.059980e+06
# mean   2.281676e+06  8.190135e+02  3.293171e+00           2.369775e+01
# std    1.317327e+06  1.059120e+03  7.876258e+00           2.015086e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00           1.000000e+00
# 25%    1.140838e+06  3.600000e+02  2.000000e-01           8.000000e+00
# 50%    2.281676e+06  6.000000e+02  1.100000e+00           2.400000e+01
# 75%    3.422515e+06  9.600000e+02  2.900000e+00           3.200000e+01
# max    4.563353e+06  8.639900e+04  3.353100e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            3.992952e+06  4.563266e+06  4.563266e+06  4.563266e+06
# mean             2.175070e+01  1.403995e+01  1.598687e+00  3.132581e-03
# std              1.785891e+01  2.475281e+01  2.875066e+00  5.304194e-01
# ...

# %%
taxi4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4563354 entries, 0 to 4563353
# Data columns (total 12 columns):
# Unnamed: 0                int64
# trip_start_timestamp      object
# trip_end_timestamp        object
# trip_seconds              float64
# trip_miles                float64
# pickup_community_area     float64
# dropoff_community_area    float64
# fare                      float64
# tips                      float64
# tolls                     float64
# trip_total                float64
# payment_type              object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 417.8+ MB

# %%
taxi4.fillna(0)
# Out:
#          Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0                 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1                 1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 2                 2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0
# 3                 3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 4                 4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
# 5                 5   2016-7-26 10:30:00  2016-7-26 10:45:00         960.0
# 6                 6    2016-7-8 16:15:00   2016-7-8 16:15:00         480.0
# 7                 7    2016-7-2 00:00:00   2016-7-2 00:15:00         600.0
# 8                 8   2016-7-28 13:30:00  2016-7-28 13:45:00         420.0
# 9                 9   2016-7-16 09:45:00  2016-7-16 10:00:00         840.0
# 10               10   2016-7-19 20:00:00  2016-7-19 20:15:00         540.0
# ...

# %%
taxi7 = pd.read_csv("taxi_trips_7_to_9.csv")

# %%
taxi7.describe()
# Out:
#          Unnamed: 0  trip_seconds    trip_miles  pickup_community_area  \
# count  4.563354e+06  4.563088e+06  4.563271e+06           4.059980e+06
# mean   2.281676e+06  8.190135e+02  3.293171e+00           2.369775e+01
# std    1.317327e+06  1.059120e+03  7.876258e+00           2.015086e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00           1.000000e+00
# 25%    1.140838e+06  3.600000e+02  2.000000e-01           8.000000e+00
# 50%    2.281676e+06  6.000000e+02  1.100000e+00           2.400000e+01
# 75%    3.422515e+06  9.600000e+02  2.900000e+00           3.200000e+01
# max    4.563353e+06  8.639900e+04  3.353100e+03           7.700000e+01
#
#        dropoff_community_area          fare          tips         tolls  \
# count            3.992952e+06  4.563266e+06  4.563266e+06  4.563266e+06
# mean             2.175070e+01  1.403995e+01  1.598687e+00  3.132581e-03
# std              1.785891e+01  2.475281e+01  2.875066e+00  5.304194e-01
# ...

# %%
taxi7.head()
# Out:
#    Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0           0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1           1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 2           2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0
# 3           3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 4           4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
#
#    trip_miles  pickup_community_area  dropoff_community_area   fare  tips  \
# 0        0.10                    8.0                    28.0  10.25  0.00
# 1        1.60                    8.0                    28.0   7.75  0.00
# 2        4.22                    NaN                     NaN  13.25  3.55
# 3        2.70                   32.0                     8.0  10.75  2.00
# 4       17.50                    8.0                    76.0  43.25  0.00
#
#    tolls  trip_total payment_type
# 0    0.0       12.75         Cash
# 1    0.0        7.75         Cash
# ...

# %%
taxi7['pickup_community_area'].index
# Out:
# RangeIndex(start=0, stop=4563354, step=1)

# %%
taxi7 = taxi7.drop(taxi7[taxi7.pickup_community_area == None].index)

# %%
taxi7.head()
# Out:
#    Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0           0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1           1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 2           2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0
# 3           3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 4           4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
#
#    trip_miles  pickup_community_area  dropoff_community_area   fare  tips  \
# 0        0.10                    8.0                    28.0  10.25  0.00
# 1        1.60                    8.0                    28.0   7.75  0.00
# 2        4.22                    NaN                     NaN  13.25  3.55
# 3        2.70                   32.0                     8.0  10.75  2.00
# 4       17.50                    8.0                    76.0  43.25  0.00
#
#    tolls  trip_total payment_type
# 0    0.0       12.75         Cash
# 1    0.0        7.75         Cash
# ...

# %%
taxi7.drop(taxi7[taxi7.pickup_community_area == np.nan].index)
# Out:
#          Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0                 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1                 1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 2                 2   2016-7-15 13:45:00  2016-7-15 14:00:00         642.0
# 3                 3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 4                 4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
# 5                 5   2016-7-26 10:30:00  2016-7-26 10:45:00         960.0
# 6                 6    2016-7-8 16:15:00   2016-7-8 16:15:00         480.0
# 7                 7    2016-7-2 00:00:00   2016-7-2 00:15:00         600.0
# 8                 8   2016-7-28 13:30:00  2016-7-28 13:45:00         420.0
# 9                 9   2016-7-16 09:45:00  2016-7-16 10:00:00         840.0
# 10               10   2016-7-19 20:00:00  2016-7-19 20:15:00         540.0
# ...

# %%
taxi3 = taxi7['pickup_community_area'].dropna()

# %%
taxi3.head()
# Out:
# 0     8.0
# 1     8.0
# 3    32.0
# 4     8.0
# 5    28.0
# Name: pickup_community_area, dtype: float64

# %%
taxi7 = taxi7.dropna(subset = ['pickup_community_area']);
taxi7 = taxi7.dropna(subset = ['dropoff_community_area'])

# %%
taxi7
# Out:
#          Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0                 0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1                 1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 3                 3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 4                 4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
# 5                 5   2016-7-26 10:30:00  2016-7-26 10:45:00         960.0
# 7                 7    2016-7-2 00:00:00   2016-7-2 00:15:00         600.0
# 8                 8   2016-7-28 13:30:00  2016-7-28 13:45:00         420.0
# 9                 9   2016-7-16 09:45:00  2016-7-16 10:00:00         840.0
# 10               10   2016-7-19 20:00:00  2016-7-19 20:15:00         540.0
# 11               11   2016-7-21 19:30:00  2016-7-21 19:30:00         480.0
# 13               13    2016-7-4 04:00:00   2016-7-4 04:00:00         360.0
# ...

# %%
taxi7.drop('Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-927d8613cb24> in <module>()
# ----> 1 taxi7.drop('Unnamed: 0')
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /Users/reiisobe/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
taxi7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3943512 entries, 0 to 4563353
# Data columns (total 12 columns):
# Unnamed: 0                int64
# trip_start_timestamp      object
# trip_end_timestamp        object
# trip_seconds              float64
# trip_miles                float64
# pickup_community_area     float64
# dropoff_community_area    float64
# fare                      float64
# tips                      float64
# tolls                     float64
# trip_total                float64
# payment_type              object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 551.1+ MB

# %%
taxi7.pop('Unnamed: 0')
# Out:
# 0                0
# 1                1
# 3                3
# 4                4
# 5                5
# 7                7
# 8                8
# 9                9
# 10              10
# 11              11
# 13              13
# 14              14
# 15              15
# 16              16
# 17              17
# 18              18
# 19              19
# 20              20
# 21              21
# 22              22
# 23              23
# 24              24
# 25              25
# 27              27
# 28              28
# 29              29
# 31              31
# 32              32
# 33              33
# 34              34
#             ...
# 4563320    4563320
# 4563322    4563322
# 4563323    4563323
# 4563325    4563325
# 4563326    4563326
# 4563327    4563327
# 4563328    4563328
# 4563330    4563330
# 4563331    4563331
# 4563332    4563332
# 4563333    4563333
# 4563334    4563334
# 4563335    4563335
# 4563336    4563336
# 4563337    4563337
# 4563338    4563338
# ...

# %%
taxi7
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0         2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1         2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 3         2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
# 4         2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0       17.50
# 5         2016-7-26 10:30:00  2016-7-26 10:45:00         960.0        2.10
# 7          2016-7-2 00:00:00   2016-7-2 00:15:00         600.0        0.00
# 8         2016-7-28 13:30:00  2016-7-28 13:45:00         420.0        0.60
# 9         2016-7-16 09:45:00  2016-7-16 10:00:00         840.0        2.30
# 10        2016-7-19 20:00:00  2016-7-19 20:15:00         540.0        4.20
# 11        2016-7-21 19:30:00  2016-7-21 19:30:00         480.0        1.00
# 13         2016-7-4 04:00:00   2016-7-4 04:00:00         360.0        2.70
# ...

# %%
taxi7 = taxi7.fillna(0)

# %%
taxi7.to_csv("taxi_trips_7_to_9-1.csv")

# %%
taxi = pd.read_csv("taxi_trips_7_to_9-1.csv")

# %%
taxi.pop('Unnamed: 0')
# Out:
# 0                0
# 1                1
# 2                3
# 3                4
# 4                5
# 5                7
# 6                8
# 7                9
# 8               10
# 9               11
# 10              13
# 11              14
# 12              15
# 13              16
# 14              17
# 15              18
# 16              19
# 17              20
# 18              21
# 19              22
# 20              23
# 21              24
# 22              25
# 23              27
# 24              28
# 25              29
# 26              31
# 27              32
# 28              33
# 29              34
#             ...
# 3943482    4563320
# 3943483    4563322
# 3943484    4563323
# 3943485    4563325
# 3943486    4563326
# 3943487    4563327
# 3943488    4563328
# 3943489    4563330
# 3943490    4563331
# 3943491    4563332
# 3943492    4563333
# 3943493    4563334
# 3943494    4563335
# 3943495    4563336
# 3943496    4563337
# 3943497    4563338
# ...

# %%
taxi
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 0         2016-7-12 16:00:00  2016-7-12 16:15:00         840.0        0.10
# 1         2016-7-31 21:45:00  2016-7-31 22:00:00         540.0        1.60
# 2         2016-7-12 23:15:00  2016-7-12 23:30:00         660.0        2.70
# 3         2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0       17.50
# 4         2016-7-26 10:30:00  2016-7-26 10:45:00         960.0        2.10
# 5          2016-7-2 00:00:00   2016-7-2 00:15:00         600.0        0.00
# 6         2016-7-28 13:30:00  2016-7-28 13:45:00         420.0        0.60
# 7         2016-7-16 09:45:00  2016-7-16 10:00:00         840.0        2.30
# 8         2016-7-19 20:00:00  2016-7-19 20:15:00         540.0        4.20
# 9         2016-7-21 19:30:00  2016-7-21 19:30:00         480.0        1.00
# 10         2016-7-4 04:00:00   2016-7-4 04:00:00         360.0        2.70
# ...

# %%
taxi.sort_values(by=['pickup_community_area','dropoff_community_area'])
# Out:
#         trip_start_timestamp  trip_end_timestamp  trip_seconds  trip_miles  \
# 610       2016-7-16 02:45:00  2016-7-16 02:45:00         240.0        0.00
# 2594      2016-7-27 14:45:00  2016-7-27 15:00:00         840.0        1.00
# 3034      2016-7-29 10:30:00  2016-7-29 10:45:00         540.0        1.30
# 3472       2016-7-7 17:00:00   2016-7-7 18:15:00        4140.0        8.60
# 3809      2016-7-12 09:30:00  2016-7-12 09:45:00         660.0        1.50
# 4590      2016-7-26 18:45:00  2016-7-26 19:15:00        1500.0        8.30
# 4874      2016-7-26 20:00:00  2016-7-26 20:15:00         660.0        2.20
# 5550      2016-7-15 22:45:00  2016-7-15 23:00:00         180.0        0.80
# 6017       2016-7-6 23:00:00   2016-7-6 23:00:00         240.0        0.00
# 7107      2016-7-29 22:45:00  2016-7-29 22:45:00         120.0        0.30
# 8562       2016-7-5 10:15:00   2016-7-5 10:15:00           6.0        0.00
# ...

# %%
taxi['pickup_community_area'].value_counts(sort = False)
# Out:
# 2.0       13256
# 3.0       53585
# 4.0       14635
# 5.0       16741
# 6.0      236590
# 7.0      169769
# 8.0     1400012
# 9.0          87
# 10.0       1784
# 11.0       5377
# 12.0        749
# 13.0       2049
# 14.0       7799
# 15.0       3073
# 16.0      13290
# 17.0        452
# 18.0         87
# 19.0       1124
# 20.0        623
# 21.0       8326
# 22.0      29786
# 23.0       1639
# 24.0     104241
# 25.0        690
# 26.0        131
# 27.0        673
# 28.0     364689
# 29.0       1140
# 30.0        563
# 31.0       2713
#          ...
# 49.0       1051
# 50.0         73
# 51.0        158
# 52.0         28
# 53.0         73
# 54.0          4
# 55.0         34
# 56.0      71005
# 57.0        213
# 58.0        411
# 59.0       3634
# 60.0       1276
# 61.0        583
# 62.0        259
# 63.0        130
# 64.0        199
# 65.0        155
# 66.0        167
# 67.0        201
# 68.0        311
# 69.0        498
# 70.0        201
# 71.0        281
# 72.0         68
# ...

# %%
taxi = taxi.sort_values(by=['pickup_community_area','dropoff_community_area']);
taxi['pickup_community_area'].value_counts()
# Out:
# 8.0     1400012
# 32.0     993712
# 28.0     364689
# 76.0     240251
# 6.0      236590
# 7.0      169769
# 24.0     104241
# 33.0      87892
# 56.0      71005
# 3.0       53585
# 77.0      37538
# 22.0      29786
# 5.0       16741
# 4.0       14635
# 1.0       13400
# 16.0      13290
# 41.0      13260
# 2.0       13256
# 21.0       8326
# 14.0       7799
# 34.0       6176
# 11.0       5377
# 35.0       4728
# 39.0       3664
# 59.0       3634
# 15.0       3073
# 31.0       2713
# 13.0       2049
# 10.0       1784
# 23.0       1639
#          ...
# 58.0        411
# 40.0        373
# 68.0        311
# 71.0        281
# 62.0        259
# 46.0        230
# 57.0        213
# 67.0        201
# 70.0        201
# 64.0        199
# 37.0        172
# 66.0        167
# 45.0        167
# 51.0        158
# 65.0        155
# 48.0        144
# 73.0        138
# 26.0        131
# 63.0        130
# 75.0         93
# 18.0         87
# 9.0          87
# 53.0         73
# 50.0         73
# ...

# %%
taxi['tolls'].value_counts()
# Out:
# 0.00      3942978
# 4.00          144
# 1.50           72
# 2.00           50
# 50.00          38
# 3.60           35
# 3.00           23
# 1.90           21
# 5.00           14
# 25.00          14
# 1.00           13
# 4.50           13
# 3.50           12
# 6.00            7
# 75.00           5
# 0.01            4
# 3.80            4
# 2.10            3
# 10.00           2
# 4.90            2
# 0.90            2
# 9.00            2
# 12.00           2
# 32.50           2
# 8.50            2
# 0.75            2
# 1.80            2
# 3.25            2
# 15.00           2
# 2.06            1
#            ...
# 3.95            1
# 0.30            1
# 0.03            1
# 1.09            1
# 7.20            1
# 53.11           1
# 39.80           1
# 0.50            1
# 3.40            1
# 2.27            1
# 1.10            1
# 3.90            1
# 90.00           1
# 80.00           1
# 0.06            1
# 6.80            1
# 34.26           1
# 18.75           1
# 11.11           1
# ...

# %%
taxi['tolls'].count
# Out:
# <bound method Series.count of 610        0.0
# 2594       0.0
# 3034       0.0
# 3472       0.0
# 3809       0.0
# 4590       0.0
# 4874       0.0
# 5550       0.0
# 6017       0.0
# 7107       0.0
# 8562       0.0
# 8747       0.0
# 10761      0.0
# 11171      0.0
# 13408      0.0
# 13864      0.0
# 13926      0.0
# 14542      0.0
# 15678      0.0
# 15934      0.0
# 15984      0.0
# 16307      0.0
# 17050      0.0
# 18224      0.0
# 19105      0.0
# 19407      0.0
# 19658      0.0
# 20556      0.0
# 20761      0.0
# 21116      0.0
#           ...
# 3929040    0.0
# 3929227    0.0
# 3929490    0.0
# 3929599    0.0
# 3930097    0.0
# 3930884    0.0
# 3931307    0.0
# 3931404    0.0
# 3931819    0.0
# 3932153    0.0
# 3933233    0.0
# 3934323    0.0
# 3935619    0.0
# 3936189    0.0
# 3936905    0.0
# 3937459    0.0
# 3939678    0.0
# 3939708    0.0
# 3939756    0.0
# 3939922    0.0
# 3940684    0.0
# 3941480    0.0
# 3941563    0.0
# 3941727    0.0
# 3942467    0.0
# 3942764    0.0
# ...

# %%
3943512 - 3942978
# Out:
# 534

# %%
taxi['pickup_community_area'].plot()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
taxi = pd.read_csv("taxi_trips_7_to_9-1.csv")
taxi.head()
# Out:
#    Unnamed: 0 trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0           0   2016-7-12 16:00:00  2016-7-12 16:15:00         840.0
# 1           1   2016-7-31 21:45:00  2016-7-31 22:00:00         540.0
# 2           3   2016-7-12 23:15:00  2016-7-12 23:30:00         660.0
# 3           4   2016-7-30 05:00:00  2016-7-30 05:15:00        1320.0
# 4           5   2016-7-26 10:30:00  2016-7-26 10:45:00         960.0
#
#    trip_miles  pickup_community_area  dropoff_community_area   fare  tips  \
# 0         0.1                    8.0                    28.0  10.25   0.0
# 1         1.6                    8.0                    28.0   7.75   0.0
# 2         2.7                   32.0                     8.0  10.75   2.0
# 3        17.5                    8.0                    76.0  43.25   0.0
# 4         2.1                   28.0                     8.0  10.75   2.0
#
#    tolls  trip_total payment_type
# 0    0.0       12.75         Cash
# 1    0.0        7.75         Cash
# ...

# %%
taxi.groupby('pickup_community_area')['fare'].count()
# Out:
# pickup_community_area
# 1.0       13400
# 2.0       13256
# 3.0       53585
# 4.0       14635
# 5.0       16741
# 6.0      236590
# 7.0      169769
# 8.0     1400012
# 9.0          87
# 10.0       1784
# 11.0       5377
# 12.0        749
# 13.0       2049
# 14.0       7799
# 15.0       3073
# 16.0      13290
# 17.0        452
# 18.0         87
# 19.0       1124
# 20.0        623
# 21.0       8326
# 22.0      29786
# 23.0       1639
# 24.0     104241
# 25.0        690
# 26.0        131
# 27.0        673
# 28.0     364689
# 29.0       1140
# 30.0        563
# 31.0       2713
# 32.0     993712
# 33.0      87892
# 34.0       6176
# 35.0       4728
# 36.0        686
# 37.0        172
# 38.0       1341
#          ...
# 40.0        373
# 41.0      13260
# 42.0       1017
# 43.0       1044
# 44.0        749
# 45.0        167
# 46.0        230
# 47.0         38
# 48.0        144
# 49.0       1051
# 50.0         73
# 51.0        158
# 52.0         28
# 53.0         73
# 54.0          4
# ...

# %%
taxi.groupby('pickup_community_area')['fare'].count().plot(kind='bar')
plt.show()

# %%
pd.options.display.max_rows = 77
#change the max display to show all counties
taxi.groupby('pickup_community_area')['fare'].count()
taxi.groupby('dropoff_community_area')['fare'].count()
# Out:
# dropoff_community_area
# 1.0       20121
# 2.0       19553
# 3.0       70777
# 4.0       27569
# 5.0       33615
# 6.0      250688
# 7.0      227400
# 8.0     1245712
# 9.0         957
# 10.0       5446
# 11.0       4466
# 12.0       2766
# 13.0       4119
# 14.0      12254
# 15.0       7520
# 16.0      21248
# 17.0       1806
# 18.0        381
# 19.0       3372
# 20.0       1915
# 21.0      15967
# 22.0      58411
# 23.0       5458
# 24.0     167753
# 25.0       2349
# 26.0        468
# 27.0       2138
# 28.0     393023
# 29.0       2697
# 30.0       2101
# 31.0      10532
# 32.0     865239
# 33.0     119904
# 34.0      10715
# 35.0      10117
# 36.0       1253
# 37.0        389
# 38.0       2915
# 39.0       5466
# 40.0        768
# 41.0      19253
# 42.0       2338
# 43.0       2044
# 44.0       1163
# 45.0        238
# 46.0        575
# 47.0         55
# 48.0        290
# 49.0       1348
# 50.0        149
# 51.0        278
# 52.0        103
# 53.0        144
# 54.0         23
# ...
