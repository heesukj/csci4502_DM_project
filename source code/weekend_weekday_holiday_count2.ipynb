# %% [markdown]
# # Weekend, Weekday, & Holiday Frequency

# %%
import math
import pandas as pd
import numpy as np
import scipy as sci
from scipy import stats
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %% [markdown]
# ## Read Data and Fill NAN with Zero

# %%
weekend_holiday = pd.read_csv('weekend_holiday_count.csv')
weekend_holiday = weekend_holiday.fillna(0)
weekend_holiday.info()
weekend_holiday.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
# weekend          31 non-null int64
# weekend_count    31 non-null int64
# weekday          31 non-null int64
# weekday_count    31 non-null int64
# holiday          31 non-null float64
# holiday_count    31 non-null float64
# dtypes: float64(2), int64(4)
# memory usage: 1.5 KB
#    weekend  weekend_count  weekday  weekday_count  holiday  holiday_count
# 0        1              1        1            364      0.0            0.0
# 1        2              4        2            361     27.0            1.0
# 2        3              5        3            360     17.0            3.0
# 3        4              3        4            362     26.0            1.0
# 4        5              3        5            362      7.0            1.0

# %% [markdown]
# ## Convert float to int and Read the reduced dataframe

# %%
# Convert float to int
weekend_holiday["holiday"] = weekend_holiday["holiday"].astype(int)
weekend_holiday["holiday_count"] = weekend_holiday["holiday_count"].astype(int)
weekend_holiday
# Out:
#     weekend  weekend_count  weekday  weekday_count  holiday  holiday_count
# 0         1              1        1            364        0              0
# 1         2              4        2            361       27              1
# 2         3              5        3            360       17              3
# 3         4              3        4            362       26              1
# 4         5              3        5            362        7              1
# 5         6              4        6            361        9              1
# 6         7              3        7            362        6              1
# 7         8              2        8            363        0              0
# 8         9              4        9            361       14              2
# 9        10              5       10            360        1              2
# 10       11              3       11            362       21              1
# ...
